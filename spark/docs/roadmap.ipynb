# %% [markdown]
# Great! 🔥 Loading 10K rows successfully means your Spark environment is ready. Now don't jump randomly into functions. Learn Spark in the order that real data engineers and data scientists use it.
#
# Here is a practical **PySpark roadmap**:
#
# ## Phase 1: Spark Fundamentals (Understand the engine)
#
# **Goal: Know what Spark is doing behind the scenes**
#
# Learn:
#
# 1. Spark architecture
#
#    * Driver
#    * Executor
#    * Cluster Manager
#    * Jobs
#    * Stages
#    * Tasks
#
# 2. Spark execution model
#
#    * Lazy evaluation
#    * Transformations vs Actions
#    * DAG (Directed Acyclic Graph)
#
# Practice:
#
# ```python
# df.show()
# df.count()
# df.explain()
# ```
#
# ---
#
# # Phase 2: DataFrame Basics (Most important)
#
# **Goal: Replace pandas thinking with Spark thinking**
#
# Learn:
#
# ### Selecting data
#
# ```python
# df.select("column")
# ```
#
# ### Filtering
#
# ```python
# df.filter(df.age > 30)
# ```
#
# ### Creating new columns
#
# ```python
# from pyspark.sql.functions import col
#
# df.withColumn("new_age", col("age")+1)
# ```
#
# ### Removing columns
#
# ```python
# df.drop("column")
# ```
#
# ### Renaming columns
#
# ```python
# df.withColumnRenamed("old","new")
# ```
#
# ---
#
# # Phase 3: Data Exploration
#
# Learn:
#
# ### Summary statistics
#
# ```python
# df.describe().show()
# ```
#
# ### Missing values
#
# ```python
# df.na.drop()
# df.na.fill()
# ```
#
# ### Unique values
#
# ```python
# df.select("city").distinct().show()
# ```
#
# ### Counting categories
#
# ```python
# df.groupBy("city").count().show()
# ```
#
# ---
#
# # Phase 4: Data Cleaning (Real-world skill)
#
# Learn:
#
# * Handling null values
# * Type conversion
# * String cleaning
# * Date/time handling
# * Duplicate removal
#
# Important functions:
#
# ```python
# trim()
# lower()
# upper()
# regexp_replace()
# to_date()
# when()
# otherwise()
# ```
#
# ---
#
# # Phase 5: Spark SQL
#
# Learn SQL inside Spark.
#
# Create temporary table:
#
# ```python
# df.createOrReplaceTempView("employees")
# ```
#
# Run SQL:
#
# ```python
# spark.sql("""
# SELECT department, avg(salary)
# FROM employees
# GROUP BY department
# """).show()
# ```
#
# ---
#
# # Phase 6: Advanced Transformations
#
# Learn:
#
# ### Joins
#
# Very important:
#
# ```python
# df1.join(df2, "id")
# ```
#
# Types:
#
# * inner
# * left
# * right
# * full
#
# ---
#
# ### Aggregations
#
# ```python
# groupBy()
# agg()
# count()
# sum()
# avg()
# max()
# min()
# ```
#
# ---
#
# # Phase 7: Window Functions (Very important for analytics)
#
# Learn:
#
# * Ranking
# * Running totals
# * Previous/next values
#
# Example:
#
# ```python
# from pyspark.sql.window import Window
# from pyspark.sql.functions import row_number
#
# window = Window.partitionBy("department") \
#                 .orderBy("salary")
#
# df.withColumn(
#     "rank",
#     row_number().over(window)
# )
# ```
#
# ---
#
# # Phase 8: Performance Optimization
#
# This separates beginners from professionals.
#
# Learn:
#
# * Partitioning
# * Repartition vs Coalesce
# * Cache/Persist
# * Broadcast joins
# * Spark UI
# * File formats
#
# Example:
#
# ```python
# df.cache()
# ```
#
# ---
#
# # Phase 9: Working with Big Data
#
# Move from CSV to:
#
# * Parquet
# * Delta Lake
# * JSON
# * Database connections
#
# Learn:
#
# ```python
# df.write.parquet()
# df.read.parquet()
# ```
#
# ---
#
# # Phase 10: Spark ML (For Data Science)
#
# After strong DataFrame skills:
#
# Learn:
#
# * Feature engineering
# * VectorAssembler
# * Pipelines
# * Classification
# * Regression
# * Clustering
#
# ---
#
# ## Project roadmap (recommended)
#
# ### Project 1 (Beginner)
#
# Employee analytics:
#
# * Load CSV
# * Clean data
# * Analyze salary
# * Department statistics
#
# ### Project 2 (Intermediate)
#
# E-commerce data:
#
# * Customer analysis
# * Sales trends
# * Product ranking
# * Window functions
#
# ### Project 3 (Advanced)
#
# Large dataset:
#
# * Millions of rows
# * Parquet storage
# * Optimization
# * Spark SQL
# * ML pipeline
#
# ---
#
# Since you already work with **Python, pandas, and data science**, I would suggest this learning order:
#
# **DataFrame API → Transformations/Actions → Spark SQL → Joins → Window Functions → Optimization → MLlib**
#
# Do not spend too much time on syntax. Focus on **how Spark executes your code**. That is the difference between using Spark and mastering Spark. 🚀
