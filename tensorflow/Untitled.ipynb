# %%
import tensorflow as tf
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
dataset = tf.data.TextLineDataset("data/demo-text.txt")

for line in dataset:
    print(line.numpy())

# %%
import tensorflow as tf

dataset = tf.data.experimental.make_csv_dataset(
    "../data_sample/best-fit-linear-regression-example.csv",
    batch_size=2,

    num_epochs=1
)


for item in dataset:
    x = item['X'].numpy()
    y = item['Result'].numpy()

    print(x)
    print(y)
